# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv(r"G:\SRAV2\homeprices.csv")
print(df)
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.xlabel("Area in sq. ft.")
plt.ylabel("Prices (in USD)")
plt.scatter(df.area,df.price,color = 'r',marker= "+")
plt.tight_layout()

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
area_df = pd.DataFrame({'area': [3300]}) #Change 3300 to any size of area 
predicted_price = reg.predict(area_df)
print(predicted_price)
# Out:
# [628715.75342466]

# %%
# y = mx + b
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %%
135.78767123*3300 + 180616.43835616432
# Out:
# 628715.7534151643

# %%
df1 = pd.read_csv(r"G:\SRAV2\areas.csv")
df1.head(3)
# Out:
#    area
# 0  1000
# 1  1500
# 2  2300

# %%
p = reg.predict(df1)

# %%
plt.xlabel("Area in sq. ft.")
plt.ylabel("Prices (in USD)")
plt.scatter(df.area,df.price,color = 'r',marker= "+")
plt.grid()
plt.plot(df.area,reg.predict(df[['area']]),color = 'blue') #reg.predict(df[['area']] give array of prices
plt.tight_layout()

# %%
df1['prices'] = p
df1.to_csv(r"G:\SRAV2\prediction.csv",index=False)
df1
# Out:
#     area        prices
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3540  6.613048e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   5490  9.260908e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9   2300  4.929281e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# 12  7100  1.144709e+06
